# %% [markdown]
# # importing libaries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['total'][45]

# %% [markdown]
# what is the overall sales trend

# %%
#grouping month year 
df.groupby('year').sum()['item_id'].reset_index()
# Out:
#    year       item_id
# 0  2020  6.974569e+10
# 1  2021  1.426612e+11

# %%
#SETTING THE FIGURE 
plt.figure(figsize=(10,6))
plt.plot(df_month['year'],df_month['item_id'])
plt.xticks(rotation='vertical',size=14)
plt.show()

# %%
df['order_date'].max()
# Out:
# '2021-09-30'

# %% [markdown]
# # . top 10 product by sales

# %%
prod_sales=df.sort_values('price',ascending=False)
prod_sales
# Out:
#          order_id  order_date    status   item_id                     sku  \
# 12900   100510800        2020  canceled  821284.0     BAGGEM5A7038AC06C9A
# 38157   100363037        2020  canceled  588634.0     ENTSAM59B7C1FA12478
# 169129  100440925        2020  canceled  722836.0     ENTSAM5A0D70359FBCA
# 81737   100385508        2020  canceled  625537.0     COMAPP5A0C479C9FD5C
# 81736   100385453        2020  canceled  625443.0     COMAPP5A0C479C9FD5C
# ...           ...         ...       ...       ...                     ...
# 23219   100358254        2020  canceled  581031.0     APPSUP59AC97600FE4A
# 23223   100358257        2020  canceled  581034.0     APPSUP59AD7E1518747
# 23224   100358258        2020  canceled  581035.0     APPSUP59AD7E1518747
# 23225   100358262        2020  canceled  581039.0     APPSUP59AD7E009A963
# 3521    100357332        2020    refund  579592.0  MEFMUN59ABBE3D7B746-11
#
#         qty_ordered      price      value  discount_amount      total  ...  \
# ...

# %%
data2=pd.read_excel('Samplestore.xlsx')
data2.head(10)
# Out:
# C:\Users\BHANDARI\an\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 5       6  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
# 6       7  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
# 7       8  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
# 8       9  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
# ...

# %%
#concise summery of data set
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
#last 5 row of data set

data2.tail(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name   Segment Country/Region         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# shape of dataset
data2.shape
# Out:
# (9994, 21)

# %%
# column present of the dataset
data2.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# chexkong missing values
data2.isna().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
 #checking missing values
data2.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
# getting descriptive summary
data2.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# # explonatery data anlysis

# %% [markdown]
# over all sales trend

# %%
data2['Order Date'].min()
# Out:
# Timestamp('2016-01-03 00:00:00')

# %%
data2['Order Date'].max()
# Out:
# Timestamp('2019-12-30 00:00:00')

# %%
df_trend=data2.groupby('Category').sum['sales'].reset_index=()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-c529e3385171> in <module>
# ----> 1 df_trend=data2.groupby('Category').sum['sales'].reset_index=()
#
# TypeError: 'method' object is not subscriptable

# %%
plt.plot(df_trend['Category'],df_trend['Sales'])
plt.figure(figsize=(10,6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0ee364f6ed4e> in <module>
# ----> 1 plt.plot(df_trend['Category'],df_trend['Sales'])
#       2 plt.figure(figsize=(10,6))
#
# TypeError: tuple indices must be integers or slices, not str

# %%
dat1=pd.read_excel('Samplestore.xlsx')
print(dat1)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...
